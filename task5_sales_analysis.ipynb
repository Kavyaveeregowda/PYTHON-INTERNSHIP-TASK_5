# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load CSV
df = pd.read_csv("task5_sales_30rows.csv")

# 2. See first few rows
print("First 5 rows:")
print(df.head())

# 3. Basic info
print("\nInfo:")
print(df.info())

print("\nSummary statistics:")
print(df.describe())

print("\nMissing values in each column:")
print(df.isna().sum())
# Out:
# First 5 rows:
#    OrderID Month    Product  Quantity  UnitPrice  TotalSales
# 0        1   Jan     Laptop         1      60000       60000
# 1        2   Jan     Laptop         2      60000      120000
# 2        3   Jan      Mouse         3        800        2400
# 3        4   Jan   Keyboard         1       1500        1500
# 4        5   Jan  Headphone         4       2000        8000
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderID     30 non-null     int64
#  1   Month       30 non-null     object
#  2   Product     30 non-null     object
#  3   Quantity    30 non-null     int64
#  4   UnitPrice   30 non-null     int64
#  5   TotalSales  30 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ KB
# None
#
# Summary statistics:
#          OrderID   Quantity     UnitPrice     TotalSales
# count  30.000000  30.000000     30.000000      30.000000
# mean   15.500000   1.866667  17730.000000   27028.333333
# std     8.803408   0.860366  24823.069081   41712.027297
# min     1.000000   1.000000    800.000000     850.000000
# 25%     8.250000   1.000000   1512.500000    2825.000000
# 50%    15.500000   2.000000   2125.000000    4875.000000
# 75%    22.750000   2.000000  15950.000000   15950.000000
# max    30.000000   4.000000  62000.000000  124000.000000
#
# Missing values in each column:
# OrderID       0
# Month         0
# Product       0
# Quantity      0
# UnitPrice     0
# TotalSales    0
# dtype: int64

# %%
sales_by_product = df.groupby("Product")["TotalSales"].sum()
print("\nTotal Sales by Product:")
print(sales_by_product)

# Total sales for each month
sales_by_month = df.groupby("Month")["TotalSales"].sum()
print("\nTotal Sales by Month:")
print(sales_by_month)
# Out:
# Total Sales by Product:
# Product
# Headphone     31500
# Keyboard      19250
# Laptop       671500
# Monitor       77500
# Mouse         11100
# Name: TotalSales, dtype: int64
#
# Total Sales by Month:
# Month
# Apr    145800
# Feb    147300
# Jan    191900
# Jun    150450
# Mar     87800
# May     87600
# Name: TotalSales, dtype: int64

# %%
plt.figure()
sales_by_product.plot(kind="bar")
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.show()

# %%
plt.figure()
sales_by_month.plot(kind="line", marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.show()
